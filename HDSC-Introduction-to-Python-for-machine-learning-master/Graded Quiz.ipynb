# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.tail()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60938                                    Food      1000 tonnes  42.00  46.00
# 60939     Food supply quantity (kg/capita/yr)               kg   3.06   3.33
# 60940           Food supply (kcal/capita/day)  kcal/capita/day   3.00   4.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day   0.10   0.11
# 60942      Fat supply quantity (g/capita/day)     g/capita/day   0.04   0.05
#
#        Y2016  Y2017  Y2018
# 60938  33.00  19.00  16.00
# 60939   2.35   1.33   1.08
# ...

# %%
# Question 11

# What is the total sum of Animal Fat produced in 2014 and 2017 respectively?
# Hint: Perform a groupby sum aggregation on ‘Item’

df.groupby('Item')['Y2014','Y2017'].count().sum()
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_16020/1807626802.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Item')['Y2014','Y2017'].count().sum()
# Y2014    59354
# Y2017    59437
# dtype: int64

# %%
# Question 12
# What is the mean and standard deviation across the whole dataset for the year 2015 to 3 decimal places?

#calculate mean of 'Y2015' column
print(df["Y2015"].mean())

#calculate standard deviation of 'Y2015' column
print(df['Y2015'].std())

# Done
# Out:
# 135.23596649549236
# 1603.4039839423301

# %%
# to 3 decimal places?
# MEAN
print(round(135.23596649549236, 3))

# STANDARD DEVIATION
print(round(1603.4039839423301, 3))

# Done
# Out:
# 135.236
# 1603.404

# %%
# Question 13
# What is the total number and percentage of missing data in 2016 to 2 decimal places?

df.groupby('Y2016').apply(lambda x: '{:.2f}%'.format((x==0).sum()/len(x)*100))
# Out:
# Area Code       60943
# Area            60943
# Item Code       60943
# Item            60943
# Element Code    60943
# Element         60943
# Unit            60943
# Y2014           60943
# Y2015           60943
# Y2016           60943
# Y2017           60943
# Y2018           60943
# dtype: int64

# %%
# Question 14
# Which year had the highest correlation with ‘Element Code’? 

df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
# Question 15
# What year has the highest sum of Import Quantity?

# Hint- Perform a groupby operation on ‘Element’ and use the resulting Dataframe to answer the question
df.groupby('Element').count()

#df.groupby(['Element']).sum().reset_index().groupby(['Element']).max().reset_index()
# Out:
#                                         Area Code  Area  Item Code  Item  \
# Element
# Domestic supply quantity                     5295  5295       5295  5295
# Export Quantity                              4403  4403       4403  4403
# Fat supply quantity (g/capita/day)           5023  5023       5023  5023
# Feed                                         1319  1319       1319  1319
# Food                                         4941  4941       4941  4941
# Food supply (kcal/capita/day)                5014  5014       5014  5014
# Food supply quantity (kg/capita/yr)          4905  4905       4905  4905
# Import Quantity                              5139  5139       5139  5139
# Losses                                       2009  2009       2009  2009
# Other uses (non-food)                        1732  1732       1732  1732
# Processing                                   2010  2010       2010  2010
# Production                                   3881  3881       3881  3881
# ...

# %%
# Question 16
# What is the total number of the sum of Production in 2014?

# Hint- Perform a groupby operation on ‘Element’ and use the resulting Dataframe to answer the question
df.groupby('Element')['Y2014'].nunique()
# Out:
# Element
# Domestic supply quantity                  1194
# Export Quantity                            409
# Fat supply quantity (g/capita/day)         688
# Feed                                       253
# Food                                      1006
# Food supply (kcal/capita/day)              505
# Food supply quantity (kg/capita/yr)       1492
# Import Quantity                            563
# Losses                                     299
# Other uses (non-food)                      184
# Processing                                 244
# Production                                1055
# Protein supply quantity (g/capita/day)     757
# Residuals                                  110
# Seed                                       126
# Stock Variation                            318
# Total Population - Both sexes               45
# Tourist consumption                          6
# Name: Y2018, dtype: int64

# %%
# Question 17
# Which of these elements had the highest sum in 2018?

# Hint-  Select columns ‘Y2018’ and ‘Element’, Perform a groupby operation
# on ‘Element’ on the selected dataframe and answer the  question.
df.groupby('Element')['Y2018'].count()

# %%
# Question 18
# Which of these elements had the 3rd lowest sum in 2018?

# Hint-  Select columns ‘Y2018’ and ‘Element’, Perform a groupby operation
# on ‘Element’ on the selected dataframe and answer the  question.
df.groupby('Element')['Y2018'].count()
# Out:
# Element
# Domestic supply quantity                  5256
# Export Quantity                           3646
# Fat supply quantity (g/capita/day)        4987
# Feed                                      1225
# Food                                      4913
# Food supply (kcal/capita/day)             4969
# Food supply quantity (kg/capita/yr)       4877
# Import Quantity                           4945
# Losses                                    2008
# Other uses (non-food)                     1655
# Processing                                2003
# Production                                3846
# Protein supply quantity (g/capita/day)    4986
# Residuals                                 4616
# Seed                                       758
# Stock Variation                           4217
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Y2018, dtype: int64

# %%
# Question 19
# What is the total Import Quantity in Algeria in 2018?

df.groupby((Algeria)['Y2018']).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16020/3024739533.py in <module>
#       2 # What is the total Import Quantity in Algeria in 2018?
#       3
# ----> 4 df.groupby((Algeria)['Y2018']).count()
#
# NameError: name 'Algeria' is not defined

# %%
# Question 20
# What is the total number of unique countries in the dataset?

df.groupby('Area').nunique()
# Out:
#                              Area Code  Item Code  Item  Element Code  \
# Area
# Algeria                              1        119   116            17
# Angola                               1        121   118            18
# Benin                                1        119   116            17
# Botswana                             1        120   117            18
# Burkina Faso                         1        121   118            17
# Cabo Verde                           1        118   115            18
# Cameroon                             1        122   119            17
# Central African Republic             1        119   116            17
# Chad                                 1        122   119            17
# Comoros                              1          9     9             7
# Congo                                1        122   119            17
# Côte d'Ivoire                        1        122   119            17
# ...
